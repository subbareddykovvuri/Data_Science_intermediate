# %% [markdown]
# #  File Handling

# %%
# driver code:
# downloads files needed for the lecture, this cell nothing to do with lecture itself
import requests

res = requests.get("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/918/original/sample.jpeg")
with open("sample.jpeg", "wb") as img:
  img.write(res.content)

# %% [markdown]
# # <u>File handling</u>
# - All our variables, functions, classes are load on RAM and get removed as the program done executing.
# - We use to save on Secondary memory in order to keep the things even when program is done executing
# - We use ASCII encoding the encode our data into numbers and then it can be stored in secondary memory
# - Everything in memory is sequence of bytes or byte array example: .exe files
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/919/original/Screenshot_2022-11-17_at_10.26.32_AM.png?1668660993">
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/921/original/Screenshot_2022-11-17_at_10.28.34_AM.png?1668661114">
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/922/original/Screenshot_2022-11-17_at_10.32.05_AM.png?1668661332">
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/923/original/Screenshot_2022-11-17_at_10.32.14_AM.png?1668661356">

# %% [markdown]
#  The Encoding code point is a unique integer assigned to each character in the and depends on encoding table being used:
#  for example 'a' is represented using integer 97 in ascii and utf-8.

# %%
import sys

# get default python encoding
encoding = sys.getdefaultencoding()

print(encoding)
# Out:
# utf-8

# %% [markdown]
# - The first 128 characters in UTF-8 are represented by 1 byte. These characters are the same as the characters in ASCII.
#
# - The next 1920 characters in UTF-8 are represented by 2 bytes.
#
# - The next 16384 characters in UTF-8 are represented by 3 bytes.
#
# - The remaining characters in UTF-8 are represented by 4 bytes.

# %%
# ord() function can be used to convert a character to its encoding code point
char = "a"
cp = ord(char)
print(cp)
# Out:
# 97

# %%
import threading

# Function to write data to a file
def write_to_file(filename, data):
    with open(filename, 'a') as f:  # Open in append mode
        f.write(data + '\n')

# Target function for threads
def thread_function(filename, data):
    write_to_file(filename, data)

# Main
if __name__ == "__main__":
    filename = "test_file.txt"
    data = ["Thread-1 writes this line", "Thread-2 writes this line", "Thread-3 writes this line"]

    # Create threads
    threads = [threading.Thread(target=thread_function, args=(filename, data[i])) for i in range(3)]

    # Start threads
    for thread in threads:
        thread.start()

    # Wait for all threads to complete
    for thread in threads:
        thread.join()

    print("Finished writing to the file.")
# Out:
# Finished writing to the file.

# %% [markdown]
# ##<u>Working with Files</u>
#
# Let's say we have some file in my memory and 2 python programs are simulatenously working on that file.
#
# Should it be allowed?
#
# Well if both are trying to read the file then it is okay, but if both are writing on the file or any of them is reading and other writing then it is a disastrous condition.
#
# We need to put lock on the access of file in such condition
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/927/original/Screenshot_2022-11-17_at_10.39.24_AM.png?1668661766">

# %% [markdown]
# ### File Access Modes
#
# >Access modes govern the type of operations possible in the opened file. It refers to how the file will be used once its opened. These modes also define the location of the File Handle in the file. File handle is like a cursor, which defines from where the data has to be read or written in the file. There are 6 access modes in python.
#
# - **Read Only (‘r’)** : Open text file for reading. The handle is positioned at the beginning of the file. If the file does not exists, raises I/O error. This is also the default mode in which file is opened.
#
#
# - **Read and Write (‘r+’)** : Open the file for reading and writing. The handle is positioned at the beginning of the file. Raises I/O error if the file does not exists.
#
#
# - **Write Only (‘w’)** : Open the file for writing. For existing file, the data is truncated and over-written. The handle is positioned at the beginning of the file. Creates the file if the file does not exists.
#
#
# - **Write and Read (‘w+’)** : Open the file for reading and writing. For existing file, data is truncated and over-written. The handle is positioned at the beginning of the file.
#
#
# - **Append Only (‘a’)** : Open the file for writing. The file is created if it does not exist. The handle is positioned at the end of the file. The data being written will be inserted at the end, after the existing data.
#
#
# - **Append and Read (‘a+’)** : Open the file for reading and writing. The file is created if it does not exist. The handle is positioned at the end of the file. The data being written will be inserted at the end, after the existing data.

# %% [markdown]
# ### Opening a file
# To open a file in Python, you can use the open() function. The open() function takes two arguments: the path of the file and the one of the above mode.
# Ex:

# %%
file = open("sample.txt", "r+")
file.write("Hello everyone from the file!")
# Out:
# 29

# %%
file = open("sample.txt", "w+")
print(type(file))
file.read()
file.seek(1000)
file.tell()
# a new sample.txt file is get created
# Out:
# <class '_io.TextIOWrapper'>
# 1000

# %%
file.close()

# %% [markdown]
# ### Closing a file
# - A File should be closed after its use
# - [Why close python file?](https://realpython.com/why-close-file-python/#:~:text=You've%20learned%20why%20it's,handles%20or%20experiencing%20corrupted%20data)
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/928/original/Screenshot_2022-11-17_at_10.45.09_AM.png?1668662110" height=400 width=400>
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/929/original/Screenshot_2022-11-17_at_10.47.11_AM.png?1668662234" height=400 width=400>

# %% [markdown]
# Why should we close the files then:
# - **To free up resources:** When you open a file, the operating system allocates resources to it, such as memory and file descriptors. These resources are not released until you close the file. So, if you keep a file open for an extended period of time, you could be wasting system resources.
# - **To prevent corruption:** When you write to a file, the data is not actually written to the disk immediately. Instead, it is buffered in memory. The data is only written to the disk when the buffer is full or when you close the file. So, if you don't close the file, there is a chance that the data in the buffer could be lost if the program crashes or the computer loses power.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Writing to a file
#
# - write
# - writelines

# %%
file = open("sample.txt", "w+")

# %%
file.write("Hello everyone from the file!")
# returns how many bytes are been written
# Out:
# 29

# %%
file.close()

# %%
file = open("sample2.txt", "w+")

# %%
file.writelines(["1\n", "2\n", "3\n"])

# %%
file.close()

# %%
file = open("sample2.txt", "r+")
print(file.read())
file.close()
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### Reading from a file
# - read
# - readline
# - readlines

# %%
file = open("sample.txt", "r+")

# %%
file.read()
# will read everything from the file and the reading cursor will be at the end and get locked there
# Out:
# ''

# %%
file.read()
# now since reading cursor is at end and there is nothing to read, hence it'll show no content
# Out:
# ''

# %%
file.write("THIS IS RANDOM")
# in r+ mode we can write too from the current reading cursor's postition
# Out:
# 14

# %%
file.read()
# reading file will again show no content because reading cursor is locked previously
# need to close and open the file again in order to read its new updated content
# Out:
# ''

# %%
file.close()

# %%
file = open("sample.txt", "r+")
print(file.read())
file.close()
# Out:
# Hello everyone from the file!THIS IS RANDOM

# %%
file = open("sample2.txt", "r+")

# %%
# reading content line by line
file.readline()
# file.seek(0)
# Out:
# 'Hello everyone from the file!THIS IS RANDOM'

# %%
file.readline()
# Out:
# ''

# %%
file.readline()
# Out:
# ''

# %%
file.readline()
# Out:
# ''

# %%
file.close()

# %%
file = open("sample2.txt", "r+")

# %%
# reading all lines at once
file.readlines()
# Out:
# ['1\n', '2\n', '3\n']

# %%
file.close()

# %%
# Option 1 -> Better for smaller files
file = open("sample2.txt", "r+")
for line in file.readlines(): # n lines = n blocks of memory
    print(line, end = "")

file.close()

# it'll load all the lines inside the memory at once
# Out:
# 1
# 2
# 3

# %%
# Option 2 -> Better for larger files
file = open("sample2.txt", "r+")

buffer = file.readline()

while buffer: # n lines = 1 block of memory
    print(buffer, end = "")
    buffer = file.readline()

file.close()

# here we are loading one line from the file at one time
# Out:
# 1
# 2
# 3

# %%
# Option 2 -> Better for larger files
file = open("sample2.txt", "r+")

while True: # n lines = 1 block of memory
    line = file.readline()

    if not line:
        break
    print(line, end = "")

file.close()
# Out:
# 1
# 2
# 3

# %%
file = open("sample3.txt", "w+")

# %%
file.writelines(["this is a line\n", "this is some random second line\n", "third line?\n"])

# %%
file.close()

# %%
# reading only certain amount of characters at once from the lines
file = open("sample3.txt", "r+")

while True:
    chunk = file.read(5) # 5 is my chunk size

    if not chunk:
        break
    print(chunk)

file.close()
# Out:
# thisi
# salin
# e
# thi
# s is
# some
# rando
# m sec
# ond l
# ine
# t
# hird
# line?

# %% [markdown]
# ###Task:
# read image and create its copy
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/019/933/original/Screenshot_2022-11-17_at_11.05.15_AM.png?1668663319">

# %%
source = open("sample.jpeg", "rb+") # b stands for binary files -> Any file encoding for which is not known

# %%
destination = open("sample2.jpeg", "wb+")

# %%
while True:
    chunk = source.read(256)
    if not chunk:
        break
    destination.write(chunk)

source.close()
destination.close()

# %% [markdown]
# ### Moving the cursor
#
# - seek(n) : takes the file read handle to the nth byte from the beginning.

# %%
file = open("sample3.txt", "r+")

# %%
file.read(15)
# Out:
# 'this is a line\n'

# %%
file.read()
# Out:
# 'this is some random second line\nthird line?\n'

# %%
file.seek(0)
# moving cursor to 0th position
# Out:
# 0

# %%
file.read()
# Out:
# 'this is a line\nthis is some random second line\nthird line?\n'

# %%
file.seek(5)
# moving cursor to 5th character
# Out:
# 5

# %%
file.read()
# Out:
# 'is a line\nthis is some random second line\nthird line?\n'

# %%
file.close()

# %% [markdown]
# ### Smarter way of opening files...
#
# With the "with" statement, you get better syntax and exceptions handling.
#
# "The with statement simplifies exception handling by encapsulating common
# preparation and cleanup tasks."
#
# In addition, the context manager will automatically close the resource/file handle when the code block is exited, even if an exception is raised. The with statement provides a way for ensuring that a clean-up is always used.

# %%
with open("sample3.txt", "r+") as file:
    print(file.read(5))
    file.seek(0)
    print(file.read())

# the file get only opened inside the with context and cannot be accessible from outside
# file.seek(5)
# Out:
# this
# this is a line
# this is some random second line
# third line?
